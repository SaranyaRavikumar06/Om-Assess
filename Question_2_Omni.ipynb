# %% [markdown]
# <a href="https://colab.research.google.com/github/SaranyaRavikumar06/Om-Assess/blob/main/Question_2_Omni.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Data Exploration, Transformation and Loading(ETL)**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("https://raw.githubusercontent.com/SaranyaRavikumar06/Om-Assess/main/predictions.csv")

# %%
df1=df

# %%
df.shape
# Out:
# (626, 11)

# %%
#Display first 10 rows of the data
df.head(10)
# Out:
#    Unnamed: 0        date  fit top 1  fit top 2  fit top 3  fit2 top 3  \
# 0           0  2012-10-07   6.464020  14.918372  12.852700   17.560586
# 1           1  2012-10-14   6.405044  14.879459  13.460605   17.584433
# 2           2  2012-10-21   5.594880  12.766397  12.500809   16.287381
# 3           3  2012-10-28   4.556118   9.883558  11.040882   14.667064
# 4           4  2012-11-04   4.203193   8.345088  10.553082   14.029395
# 5           5  2012-11-11   4.907368   8.923720  11.374599   14.621175
# 6           6  2012-11-18   6.035311  10.469797  12.440276   15.424591
# 7           7  2012-11-25   6.568955  11.273127  12.450489   15.232878
# 8           8  2012-12-02   6.166446  10.646426  11.166618   13.826368
# 9           9  2012-12-09   5.477106   9.139947   9.545315   12.095790
#
#    fit3 top 3  fit2 top 2  fit3 top 2  fit2 top 1  fit3 top 1
# 0   16.691433   21.967562   19.348604    6.676299    6.814028
# 1   16.864402   20.428943   18.149665    6.553469    6.678460
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626 entries, 0 to 625
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  626 non-null    int64
#  1   date        626 non-null    object
#  2   fit top 1   626 non-null    float64
#  3   fit top 2   626 non-null    float64
#  4   fit top 3   626 non-null    float64
#  5   fit2 top 3  626 non-null    float64
#  6   fit3 top 3  626 non-null    float64
#  7   fit2 top 2  626 non-null    float64
#  8   fit3 top 2  626 non-null    float64
#  9   fit2 top 1  626 non-null    float64
#  10  fit3 top 1  626 non-null    float64
# dtypes: float64(9), int64(1), object(1)
# memory usage: 53.9+ KB

# %%
df.describe()
# Out:
#        Unnamed: 0   fit top 1   fit top 2   fit top 3  fit2 top 3  fit3 top 3  \
# count  626.000000  626.000000  626.000000  626.000000  626.000000  626.000000
# mean   312.500000   15.792292   69.791001   32.249881   32.004939   31.895551
# std    180.854914    5.939152   32.946941    8.808045    8.910247    8.934187
# min      0.000000    3.409713    6.166742    8.740487   11.133820   11.350117
# 25%    156.250000   14.987423   32.714805   26.747984   26.553807   26.327755
# 50%    312.500000   17.607248   80.605119   34.027927   32.933962   32.636063
# 75%    468.750000   19.762297   98.681039   39.416604   39.507346   39.543204
# max    625.000000   25.552484  109.182507   44.181066   44.638694   44.827019
#
#        fit2 top 2  fit3 top 2  fit2 top 1  fit3 top 1
# count  626.000000  626.000000  626.000000  626.000000
# mean    58.889299   55.834099   16.015668   16.034296
# std     26.329259   25.351693    6.097955    6.113293
# ...

# %%
#Check for missing values
df.isnull().sum()
# Out:
# Unnamed: 0    0
# date          0
# fit top 1     0
# fit top 2     0
# fit top 3     0
# fit2 top 3    0
# fit3 top 3    0
# fit2 top 2    0
# fit3 top 2    0
# fit2 top 1    0
# fit3 top 1    0
# dtype: int64

# %%
# Drop first column of dataframe since it does not add any importance to the dataset
df = df.iloc[: , 1:]

# %%
df
# Out:
#            date  fit top 1  fit top 2  fit top 3  fit2 top 3  fit3 top 3  \
# 0    2012-10-07   6.464020  14.918372  12.852700   17.560586   16.691433
# 1    2012-10-14   6.405044  14.879459  13.460605   17.584433   16.864402
# 2    2012-10-21   5.594880  12.766397  12.500809   16.287381   15.672930
# 3    2012-10-28   4.556118   9.883558  11.040882   14.667064   14.128378
# 4    2012-11-04   4.203193   8.345088  10.553082   14.029395   13.566908
# ..          ...        ...        ...        ...         ...         ...
# 621  2018-09-27  16.588328  98.782168  36.344867   36.316258   36.037766
# 622  2018-09-28  16.655365  98.884051  36.503322   36.415425   36.139121
# 623  2018-09-29  16.724295  99.019655  36.689969   36.538825   36.265359
# 624  2018-09-30  16.794364  99.184409  36.900044   36.682254   36.412168
# 625  2018-10-01  16.864604  99.372937  37.128318   36.841104   36.574825
#
#      fit2 top 2  fit3 top 2  fit2 top 1  fit3 top 1
# ...

# %%
#Extract year,month and day from the date column and create new columns
df['year'] = pd.DatetimeIndex(df['date']).year
df['month'] = pd.DatetimeIndex(df['date']).month
df['Day'] = pd.DatetimeIndex(df['date']).day

# %%
#Set index as the year column
df.set_index('year', inplace=True)

# %%
df
# Out:
#             date  fit top 1  fit top 2  fit top 3  fit2 top 3  fit3 top 3  \
# year
# 2012  2012-10-07   6.464020  14.918372  12.852700   17.560586   16.691433
# 2012  2012-10-14   6.405044  14.879459  13.460605   17.584433   16.864402
# 2012  2012-10-21   5.594880  12.766397  12.500809   16.287381   15.672930
# 2012  2012-10-28   4.556118   9.883558  11.040882   14.667064   14.128378
# 2012  2012-11-04   4.203193   8.345088  10.553082   14.029395   13.566908
# ...          ...        ...        ...        ...         ...         ...
# 2018  2018-09-27  16.588328  98.782168  36.344867   36.316258   36.037766
# 2018  2018-09-28  16.655365  98.884051  36.503322   36.415425   36.139121
# 2018  2018-09-29  16.724295  99.019655  36.689969   36.538825   36.265359
# 2018  2018-09-30  16.794364  99.184409  36.900044   36.682254   36.412168
# 2018  2018-10-01  16.864604  99.372937  37.128318   36.841104   36.574825
#
#       fit2 top 2  fit3 top 2  fit2 top 1  fit3 top 1  month  Day
# year
# ...

# %%
#Average Fitness top 1-Wise
cols=['fit top 1','fit2 top 1','fit3 top 1']
df['averagefit_top1']=df[cols].mean(axis=1)
df['averagefit_top1']
# Out:
# year
# 2012     6.651449
# 2012     6.545658
# 2012     5.694234
# 2012     4.620216
# 2012     4.233940
#           ...
# 2018    17.209733
# 2018    17.272444
# 2018    17.336972
# 2018    17.402568
# 2018    17.468266
# Name: averagefit_top1, Length: 626, dtype: float64

# %%
#Average Fitness top 2-Wise
cols=['fit top 2','fit2 top 2','fit3 top 2']
df['averagefit_top2']=df[cols].mean(axis=1)
df['averagefit_top2']
# Out:
# year
# 2012    18.744846
# 2012    17.819356
# 2012    15.307250
# 2012    12.460832
# 2012    11.070016
#           ...
# 2018    78.863457
# 2018    78.768917
# 2018    78.697427
# 2018    78.645385
# 2018    78.608558
# Name: averagefit_top2, Length: 626, dtype: float64

# %%
#Average Fitness top 3-Wise
cols=['fit top 3','fit2 top 3','fit3 top 3']
df['averagefit_top3']=df[cols].mean(axis=1)
df['averagefit_top3']
# Out:
# year
# 2012    15.701573
# 2012    15.969813
# 2012    14.820374
# 2012    13.278775
# 2012    12.716462
#           ...
# 2018    36.232964
# 2018    36.352622
# 2018    36.498051
# 2018    36.664822
# 2018    36.848082
# Name: averagefit_top3, Length: 626, dtype: float64

# %%
#Average Score for Fit1"
cols=['fit top 1','fit top 2','fit top 3']
df['averagescore_fit1']=df[cols].mean(axis=1)
df['averagescore_fit1']
# Out:
# year
# 2012    11.411698
# 2012    11.581703
# 2012    10.287362
# 2012     8.493519
# 2012     7.700454
#           ...
# 2018    50.571788
# 2018    50.680912
# 2018    50.811306
# 2018    50.959606
# 2018    51.121953
# Name: averagescore_fit1, Length: 626, dtype: float64

# %%
#Average Score for Fit2"
cols=['fit2 top 1','fit2 top 2','fit2 top 3']
df['averagescore_fit2']=df[cols].mean(axis=1)
df['averagescore_fit2']
# Out:
# year
# 2012    15.401483
# 2012    14.855615
# 2012    13.169070
# 2012    11.248005
# 2012    10.374968
#           ...
# 2018    42.360574
# 2018    42.362200
# 2018    42.378814
# 2018    42.407729
# 2018    42.445863
# Name: averagescore_fit2, Length: 626, dtype: float64

# %%
#Average Score for Fit3"
cols=['fit3 top 1','fit3 top 2','fit3 top 3']
df['averagescore_fit3']=df[cols].mean(axis=1)
df['averagescore_fit3']
# Out:
# year
# 2012    14.284689
# 2012    13.897509
# 2012    12.365426
# 2012    10.618298
# 2012     9.944996
#           ...
# 2018    39.373792
# 2018    39.350871
# 2018    39.342330
# 2018    39.345441
# 2018    39.357091
# Name: averagescore_fit3, Length: 626, dtype: float64

# %% [markdown]
# # **New Dataset based on average score-Topwise(Top 1 ,Top 2 ,Top 3)**

# %%
Topwisefit_df=df.iloc[:,13:16]
Topwisefit_df
# Out:
#       averagefit_top2  averagefit_top3  averagescore_fit1
# year
# 2012        18.744846        15.701573          11.411698
# 2012        17.819356        15.969813          11.581703
# 2012        15.307250        14.820374          10.287362
# 2012        12.460832        13.278775           8.493519
# 2012        11.070016        12.716462           7.700454
# ...               ...              ...                ...
# 2018        78.863457        36.232964          50.571788
# 2018        78.768917        36.352622          50.680912
# 2018        78.697427        36.498051          50.811306
# 2018        78.645385        36.664822          50.959606
# 2018        78.608558        36.848082          51.121953
#
# [626 rows x 3 columns]

# %% [markdown]
# **Finding Trend**

# %%
Topwisefit_df.plot(grid=True,figsize=(15,6)).autoscale(axis='x',tight=True)

# %%
#Line Plot
# get columns to plot
columns = Topwisefit_df.columns[0:3]
# create x data
x_data = range(0, Topwisefit_df.shape[0])
# create figure and axis
fig, ax = plt.subplots(figsize=(15,6))
# plot each column
for column in columns:
    ax.plot(x_data, Topwisefit_df[column], label=column)
# set title and legend
ax.set_title('Trends Dataset -Top Wise')
ax.legend()

# %% [markdown]
# **From the above graph, we can find that the average fit for "Top 2" is high on three type of fits when compared with "Top 1"and "Top 3"**

# %% [markdown]
# # **New Dataset based on average score-Fitwise(Fit ,Fit 2 ,Fit 3)**

# %%
Fitwise_df=df.iloc[:,16:119]
Fitwise_df
# Out:
#       averagescore_fit2  averagescore_fit3
# year
# 2012          15.401483          14.284689
# 2012          14.855615          13.897509
# 2012          13.169070          12.365426
# 2012          11.248005          10.618298
# 2012          10.374968           9.944996
# ...                 ...                ...
# 2018          42.360574          39.373792
# 2018          42.362200          39.350871
# 2018          42.378814          39.342330
# 2018          42.407729          39.345441
# 2018          42.445863          39.357091
#
# [626 rows x 2 columns]

# %% [markdown]
# **Finding Trend FitWise**

# %%
Fitwise_df.plot(figsize=(15,6)).autoscale(axis='x',tight=True)

# %%
#Line Plot
# get columns to plot
columns = Fitwise_df.columns[0:3]
# create x data
x_data = range(0, Fitwise_df.shape[0])
# create figure and axis
fig, ax = plt.subplots(figsize=(15,6))
# plot each column
for column in columns:
    ax.plot(x_data, Fitwise_df[column], label=column)
# set title and legend
ax.set_title('Trends Dataset -Fit Wise')
ax.set_xlabel("Values on the row from 0 to 626 in FitWise Dataset")
ax.set_ylabel("Average Score")
ax.legend()

# %% [markdown]
# **From the above graph, we can find that the average score for "Fit 1" is high on three type of tops when compared with "Fit 2"and "Fit 3"**

# %% [markdown]
# # **Question 2**
# Quantify these predictions into an assessment of how you would expect the demand to change over the next 3, 6, 12 months.

# %%
df1
# Out:
#      Unnamed: 0        date  fit top 1  fit top 2  fit top 3  fit2 top 3  \
# 0             0  2012-10-07   6.464020  14.918372  12.852700   17.560586
# 1             1  2012-10-14   6.405044  14.879459  13.460605   17.584433
# 2             2  2012-10-21   5.594880  12.766397  12.500809   16.287381
# 3             3  2012-10-28   4.556118   9.883558  11.040882   14.667064
# 4             4  2012-11-04   4.203193   8.345088  10.553082   14.029395
# ..          ...         ...        ...        ...        ...         ...
# 621         621  2018-09-27  16.588328  98.782168  36.344867   36.316258
# 622         622  2018-09-28  16.655365  98.884051  36.503322   36.415425
# 623         623  2018-09-29  16.724295  99.019655  36.689969   36.538825
# 624         624  2018-09-30  16.794364  99.184409  36.900044   36.682254
# 625         625  2018-10-01  16.864604  99.372937  37.128318   36.841104
#
#      fit3 top 3  fit2 top 2  fit3 top 2  fit2 top 1  fit3 top 1
# ...

# %%
#Set index as the year column
df1.set_index('date', inplace=True)

# %%
# Drop first column of dataframe since it does not add any importance to the dataset
df1 = df1.iloc[: , 1:]

# %%
df1.tail()
# Out:
#             fit top 1  fit top 2  fit top 3  fit2 top 3  fit3 top 3  \
# date
# 2018-09-27  16.588328  98.782168  36.344867   36.316258   36.037766
# 2018-09-28  16.655365  98.884051  36.503322   36.415425   36.139121
# 2018-09-29  16.724295  99.019655  36.689969   36.538825   36.265359
# 2018-09-30  16.794364  99.184409  36.900044   36.682254   36.412168
# 2018-10-01  16.864604  99.372937  37.128318   36.841104   36.574825
#
#             fit2 top 2  fit3 top 2  fit2 top 1  fit3 top 1
# date
# 2018-09-27   73.258258   64.549945   17.507205   17.533665
# 2018-09-28   73.103604   64.319097   17.567572   17.594394
# 2018-09-29   72.967858   64.104769   17.629760   17.656862
# 2018-09-30   72.847916   63.903832   17.693017   17.720324
# 2018-10-01   72.740112   63.712625   17.756372   17.783823

# %% [markdown]
# **Pattern in observation over time**

# %%
from matplotlib import pyplot
pyplot.figure(figsize=(12, 12), dpi=80)
for i in range(len(df1.columns)):
	pyplot.subplot(len(df1.columns), 1, i+1)
	name = df1.columns[i]
	pyplot.plot(df1[name])
	pyplot.title(name, y=0)
pyplot.show()

# %%
df1.shape
# Out:
# (626, 9)

# %% [markdown]
# Check Stationarity

# %%
#checking stationarity
from statsmodels.tsa.vector_ar.vecm import coint_johansen
#since the test works for only 12 variables, I have randomly dropped
#in the next iteration, I would drop another and check the eigenvalues
#johan_test_temp = data.drop([ 'CO(GT)'], axis=1)
coint_johansen(df1,-1,1).eig
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# array([0.15940585, 0.12942986, 0.10221684, 0.07281845, 0.04509842,
#        0.03439309, 0.02126003, 0.00615497, 0.00016352])

# %% [markdown]
# # **Multivariate Time Series(Using VAR Model)**

# %% [markdown]
# Question 3:create your own prediction model based on the three types of tops.

# %%
#creating the train and validation set
train = df1[:int(0.8*(len(df1)))]
valid = df1[int(0.8*(len(df1))):]

#fit the model
from statsmodels.tsa.vector_ar.var_model import VAR

model = VAR(endog=train)
model_fit = model.fit()

# make prediction on validation
prediction = model_fit.forecast(model_fit.y, steps=len(valid))
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/wrapper.py:35: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)

# %%
prediction
# Out:
# array([[ 16.34817689, 105.10541813,  43.2118947 , ...,  88.50029765,
#          17.17740102,  17.2800314 ],
#        [ 16.2684362 , 105.17983761,  43.13355782, ...,  88.78175412,
#          17.0792491 ,  17.18096599],
#        [ 16.18600599, 105.23906603,  43.05153618, ...,  89.04065604,
#          16.97593628,  17.07646002],
#        ...,
#        [  9.43656492,  78.33349878,  34.19031164, ...,  56.54405907,
#           9.31201326,   9.36183095],
#        [  9.41855756,  78.13361543,  34.13907584, ...,  56.36783415,
#           9.28375664,   9.33224549],
#        [  9.40131235,  77.93447077,  34.08861126, ...,  56.18984678,
#           9.25663924,   9.3038164 ]])

# %% [markdown]
# The predictions are in the form of an array, where each list represents the predictions of the row. We will transform this into a more presentable format.

# %%
#converting predictions to dataframe
cols = df1.columns
pred = pd.DataFrame(index=range(0,len(prediction)),columns=[cols])
for j in range(0,9):
    for i in range(0, len(prediction)):
       pred.iloc[i][j] = prediction[i][j]
pred
# Out:
#      fit top 1   fit top 2  fit top 3 fit2 top 3 fit3 top 3 fit2 top 2  \
# 0    16.348177  105.105418  43.211895  43.679659  43.871441  89.531647
# 1    16.268436  105.179838  43.133558   43.61823  43.820259  89.816889
# 2    16.186006  105.239066  43.051536  43.549754  43.761664  90.079784
# 3    16.101006  105.283045  42.965986  43.474435  43.695824  90.319428
# 4    16.013562  105.311752  42.877072   43.39249  43.622924  90.535005
# ..         ...         ...        ...        ...        ...        ...
# 121   9.474766   78.735078  34.294941  34.069656  34.265391  60.243483
# 122    9.45531   78.534019   34.24228  34.014993  34.210591  60.070709
# 123   9.436565   78.333499  34.190312  33.960726   34.15609  59.895606
# 124   9.418558   78.133615  34.139076  33.906929   34.10197  59.718346
# 125   9.401312   77.934471  34.088611  33.853676  34.048307  59.539115
#
#     fit3 top 2 fit2 top 1 fit3 top 1
# 0    88.500298  17.177401  17.280031
# 1    88.781754  17.079249  17.180966
# ...

# %%
#check rmse
from numpy import sqrt 
from sklearn.metrics import mean_squared_error
for i in cols:
    print('rmse value for', i, 'is : ', sqrt(mean_squared_error(pred[i], valid[i])))
# Out:
# rmse value for fit top 1 is :  4.562904736285391
# rmse value for fit top 2 is :  14.213639457334803
# rmse value for fit top 3 is :  3.4250172733791193
# rmse value for fit2 top 3 is :  4.133251847300037
# rmse value for fit3 top 3 is :  4.012433997471645
# rmse value for fit2 top 2 is :  12.299009097801703
# rmse value for fit3 top 2 is :  9.532947549478221
# rmse value for fit2 top 1 is :  5.573344145735597
# rmse value for fit3 top 1 is :  5.557203621274273

# %% [markdown]
# After the testing on validation set, lets fit the model on the complete dataset

# %%
#make final predictions
model = VAR(endog=df1)
model_fit = model.fit()
model_fit
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)

# %% [markdown]
# # **Forecasting**

# %% [markdown]
# **Forecast for next 3 months**

# %%
#Forecast the next value for the dataset
yhat = model_fit.forecast(model_fit.y, steps=3)
print(yhat)
# Out:
# [[16.87486087 99.19317218 37.08285475 36.78733297 36.52197687 72.55534989
#   63.49668057 17.76586372 17.79425148]
#  [16.88529702 99.01469613 37.03777935 36.73456528 36.46990098 72.3743145
#   63.28355407 17.77509043 17.8044104 ]
#  [16.89588787 98.83753107 36.99304323 36.68270718 36.41851355 72.19692147
#   63.07328315 17.78399578 17.81423539]]
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/wrapper.py:35: FutureWarning: y is a deprecated alias for endog, will be removed in version 0.11.0
#   obj = getattr(results, attr)

# %%
#converting forecast to dataframe
cols = df1.columns
forecastvalues = pd.DataFrame(index=range(0,len(yhat)),columns=[cols])
for j in range(0,9):
    for i in range(0, len(yhat)):
       forecastvalues.iloc[i][j] = yhat[i][j]
forecastvalues
# Out:
#    fit top 1  fit top 2  fit top 3 fit2 top 3 fit3 top 3 fit2 top 2  \
# 0  16.874861  99.193172  37.082855  36.787333  36.521977   72.55535
# 1  16.885297  99.014696  37.037779  36.734565  36.469901  72.374314
# 2  16.895888  98.837531  36.993043  36.682707  36.418514  72.196921
#
#   fit3 top 2 fit2 top 1 fit3 top 1
# 0  63.496681  17.765864  17.794251
# 1  63.283554   17.77509   17.80441
# 2  63.073283  17.783996  17.814235

# %% [markdown]
# **Forecast next 6 months**

# %%
#Forecast the next 6 months value for the dataset
yhat1 = model_fit.forecast(model_fit.y, steps=6)
print(yhat1)

# %%
#converting forecast to dataframe
cols = df1.columns
forecastvalues1 = pd.DataFrame(index=range(0,len(yhat1)),columns=[cols])
for j in range(0,9):
    for i in range(0, len(yhat1)):
       forecastvalues1.iloc[i][j] = yhat1[i][j]
forecastvalues1

# %% [markdown]
# **Forecast for next 12 months**

# %%
#Forecast the next 12 months value for the dataset
yhat2 = model_fit.forecast(model_fit.y, steps=12)
print(yhat2)

# %%
#converting forecast to dataframe
cols = df1.columns
forecastvalues2 = pd.DataFrame(index=range(0,len(yhat2)),columns=[cols])
for j in range(0,9):
    for i in range(0, len(yhat2)):
       forecastvalues2.iloc[i][j] = yhat2[i][j]
forecastvalues2

# %% [markdown]
# # **Question 3:**

# %% [markdown]
# #**prediction model based on the three types of tops**

# %% [markdown]
# MTS and VectorARIMA

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.statespace.varmax import VARMAX
import numpy as np
from statsmodels.tsa.stattools import adfuller
from sklearn import metrics
from timeit import default_timer as timer

# %% [markdown]
# # **Data Exploration of Time Series**

# %%
# load dataset
dataset = pd.read_csv('https://raw.githubusercontent.com/SaranyaRavikumar06/Om-Assess/main/predictions.csv')

# %%
data=dataset
data=data.iloc[:,1:]
data
# Out:
#            date  fit top 1  fit top 2  fit top 3  fit2 top 3  fit3 top 3  \
# 0    2012-10-07   6.464020  14.918372  12.852700   17.560586   16.691433
# 1    2012-10-14   6.405044  14.879459  13.460605   17.584433   16.864402
# 2    2012-10-21   5.594880  12.766397  12.500809   16.287381   15.672930
# 3    2012-10-28   4.556118   9.883558  11.040882   14.667064   14.128378
# 4    2012-11-04   4.203193   8.345088  10.553082   14.029395   13.566908
# ..          ...        ...        ...        ...         ...         ...
# 621  2018-09-27  16.588328  98.782168  36.344867   36.316258   36.037766
# 622  2018-09-28  16.655365  98.884051  36.503322   36.415425   36.139121
# 623  2018-09-29  16.724295  99.019655  36.689969   36.538825   36.265359
# 624  2018-09-30  16.794364  99.184409  36.900044   36.682254   36.412168
# 625  2018-10-01  16.864604  99.372937  37.128318   36.841104   36.574825
#
#      fit2 top 2  fit3 top 2  fit2 top 1  fit3 top 1
# ...

# %%
#Convert date column from string to datettime object
data['Date']= pd.to_datetime(data['date'])

# %%
data=data.iloc[:,1:]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626 entries, 0 to 625
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   fit top 1   626 non-null    float64
#  1   fit top 2   626 non-null    float64
#  2   fit top 3   626 non-null    float64
#  3   fit2 top 3  626 non-null    float64
#  4   fit3 top 3  626 non-null    float64
#  5   fit2 top 2  626 non-null    float64
#  6   fit3 top 2  626 non-null    float64
#  7   fit2 top 1  626 non-null    float64
#  8   fit3 top 1  626 non-null    float64
#  9   Date        626 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(9)
# memory usage: 49.0 KB

# %%
data.isnull().sum()
# Out:
# fit top 1     0
# fit top 2     0
# fit top 3     0
# fit2 top 3    0
# fit3 top 3    0
# fit2 top 2    0
# fit3 top 2    0
# fit2 top 1    0
# fit3 top 1    0
# Date          0
# dtype: int64

# %%
data=data.set_index('Date')
data
# Out:
#             fit top 1  fit top 2  fit top 3  fit2 top 3  fit3 top 3  \
# Date
# 2012-10-07   6.464020  14.918372  12.852700   17.560586   16.691433
# 2012-10-14   6.405044  14.879459  13.460605   17.584433   16.864402
# 2012-10-21   5.594880  12.766397  12.500809   16.287381   15.672930
# 2012-10-28   4.556118   9.883558  11.040882   14.667064   14.128378
# 2012-11-04   4.203193   8.345088  10.553082   14.029395   13.566908
# ...               ...        ...        ...         ...         ...
# 2018-09-27  16.588328  98.782168  36.344867   36.316258   36.037766
# 2018-09-28  16.655365  98.884051  36.503322   36.415425   36.139121
# 2018-09-29  16.724295  99.019655  36.689969   36.538825   36.265359
# 2018-09-30  16.794364  99.184409  36.900044   36.682254   36.412168
# 2018-10-01  16.864604  99.372937  37.128318   36.841104   36.574825
#
#             fit2 top 2  fit3 top 2  fit2 top 1  fit3 top 1
# Date
# 2012-10-07   21.967562   19.348604    6.676299    6.814028
# ...

# %%
data[data.columns]
# Out:
#             fit top 1  fit top 2  fit top 3  fit2 top 3  fit3 top 3  \
# Date
# 2012-10-07   6.464020  14.918372  12.852700   17.560586   16.691433
# 2012-10-14   6.405044  14.879459  13.460605   17.584433   16.864402
# 2012-10-21   5.594880  12.766397  12.500809   16.287381   15.672930
# 2012-10-28   4.556118   9.883558  11.040882   14.667064   14.128378
# 2012-11-04   4.203193   8.345088  10.553082   14.029395   13.566908
# ...               ...        ...        ...         ...         ...
# 2018-09-27  16.588328  98.782168  36.344867   36.316258   36.037766
# 2018-09-28  16.655365  98.884051  36.503322   36.415425   36.139121
# 2018-09-29  16.724295  99.019655  36.689969   36.538825   36.265359
# 2018-09-30  16.794364  99.184409  36.900044   36.682254   36.412168
# 2018-10-01  16.864604  99.372937  37.128318   36.841104   36.574825
#
#             fit2 top 2  fit3 top 2  fit2 top 1  fit3 top 1
# Date
# 2012-10-07   21.967562   19.348604    6.676299    6.814028
# ...

# %% [markdown]
# # **Visulaize the time Series**

# %%
# Plot
fig, axes = plt.subplots(nrows=3, ncols=3, dpi=120, figsize=(10,6))
for i, ax in enumerate(axes.flatten()):
    data1 = data[data.columns[i]]
    ax.plot(data1, color='red', linewidth=1)
    # Decorations
    ax.set_title(data.columns[i])
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.tight_layout();

# %% [markdown]
# Each of the series have a fairly similar trend patterns over the years based on the "Top" type such as "TOP 1" have similar trend for different fit
# and "TOP 2" have similar trend for different fit as well as "Top 3"

# %% [markdown]
# **Create a function to perform ADF Test**

# %%
def Augmented_Dickey_Fuller_Test_func(series , column_name):
    print (f'Results of Dickey-Fuller Test for column: {column_name}')
    dftest = adfuller(series, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','No Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
       dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)
    if dftest[1] <= 0.05:
        print("Conclusion:")
        print("Reject the null hypothesis")
        print("Data is stationary")
    else:
        print("Conclusion:")
        print("Fail to reject the null hypothesis")
        print("series is non-stationary")

# %% [markdown]
# # **Check for Stationarity**

# %% [markdown]
# **Apply the ADF Test**

# %%
for name, column in data[['fit top 1','fit top 2','fit top 3','fit2 top 3','fit3 top 3','fit2 top 2','fit3 top 2','fit2 top 1','fit3 top 1']].iteritems():
  Augmented_Dickey_Fuller_Test_func(data[name],name)
  print('\n')
# Out:
# Results of Dickey-Fuller Test for column: fit top 1
# Test Statistic                  -1.947340
# p-value                          0.310129
# No Lags Used                    19.000000
# Number of Observations Used    606.000000
# Critical Value (1%)             -3.441187
# Critical Value (5%)             -2.866321
# Critical Value (10%)            -2.569316
# dtype: float64
# Conclusion:
# Fail to reject the null hypothesis
# series is non-stationary
#
#
# Results of Dickey-Fuller Test for column: fit top 2
# Test Statistic                  -1.324831
# p-value                          0.617737
# No Lags Used                    19.000000
# Number of Observations Used    606.000000
# Critical Value (1%)             -3.441187
# Critical Value (5%)             -2.866321
# Critical Value (10%)            -2.569316
# dtype: float64
# Conclusion:
# Fail to reject the null hypothesis
# series is non-stationary
#
#
# Results of Dickey-Fuller Test for column: fit top 3
# ...

# %% [markdown]
# # **Split the Series into Training and Testing Data**

# %%
X = data[['fit top 1','fit top 2','fit top 3','fit2 top 3','fit3 top 3','fit2 top 2','fit3 top 2','fit2 top 1','fit3 top 1']]
train = X[:int(0.8*(len(data)))]
test= X[int(0.8*(len(data))):]

# %%
train.shape
# Out:
# (500, 9)

# %%
test.shape
# Out:
# (126, 9)

# %%
train_diff = train.diff()
train_diff.dropna(inplace = True)

# %% [markdown]
# **Apply differentiation to make the data stationary**

# %%
for name, column in train_diff[['fit top 1','fit top 2','fit top 3','fit2 top 3','fit3 top 3','fit2 top 2','fit3 top 2','fit2 top 1','fit3 top 1']].iteritems():
    Augmented_Dickey_Fuller_Test_func(train_diff[name],name)
    print('\n')
# Out:
# Results of Dickey-Fuller Test for column: fit top 1
# Test Statistic                  -4.212234
# p-value                          0.000628
# No Lags Used                    18.000000
# Number of Observations Used    480.000000
# Critical Value (1%)             -3.444047
# Critical Value (5%)             -2.867580
# Critical Value (10%)            -2.569987
# dtype: float64
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: fit top 2
# Test Statistic                -6.296183e+00
# p-value                        3.501344e-08
# No Lags Used                   1.800000e+01
# Number of Observations Used    4.800000e+02
# Critical Value (1%)           -3.444047e+00
# Critical Value (5%)           -2.867580e+00
# Critical Value (10%)          -2.569987e+00
# dtype: float64
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: fit top 3
# ...

# %% [markdown]
# # **Cointegration Test**
# Cointegration test helps to establish the presence of a statistically significant connection between two or more time series.

# %%
from statsmodels.tsa.vector_ar.vecm import coint_johansen

def cointegration_test(df): 
    res = coint_johansen(df,-1,5)
    d = {'0.90':0, '0.95':1, '0.99':2}
    traces = res.lr1
    cvts = res.cvt[:, d[str(1-0.05)]]
    def adjust(val, length= 6): 
        return str(val).ljust(length)
    print('Column Name   >  Test Stat > C(95%)    =>   Signif  \n', '--'*20)
    for col, trace, cvt in zip(df.columns, traces, cvts):
        print(adjust(col), '> ', adjust(round(trace,2), 9), ">", adjust(cvt, 8), ' =>  ' , trace > cvt)

# %%
cointegration_test(train_diff[['fit top 1','fit top 2','fit top 3','fit2 top 3','fit3 top 3','fit2 top 2','fit3 top 2','fit2 top 1','fit3 top 1']])
# Out:
# Column Name   >  Test Stat > C(95%)    =>   Signif
#  ----------------------------------------
# fit top 1 >  491.39    > 179.5199  =>   True
# fit top 2 >  369.84    > 143.6691  =>   True
# fit top 3 >  270.09    > 111.7797  =>   True
# fit2 top 3 >  201.28    > 83.9383   =>   True
# fit3 top 3 >  137.76    > 60.0627   =>   True
# fit2 top 2 >  101.71    > 40.1749   =>   True
# fit3 top 2 >  70.48     > 24.2761   =>   True
# fit2 top 1 >  41.68     > 12.3212   =>   True
# fit3 top 1 >  17.05     > 4.1296    =>   True

# %% [markdown]
# When two or more time series are cointegrated, it means they have a long run, statistically significant relationship.

# %% [markdown]
# **How to Select the Order (P) of VAR model**

# %%
model = VAR(train_diff)
for i in [1,2,3,4,5,6,7,8,9]:
    result = model.fit(i)
    print('Lag Order =', i)
    print('AIC : ', result.aic)
    print('BIC : ', result.bic)
    print('FPE : ', result.fpe)
    print('HQIC: ', result.hqic, '\n')
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# Lag Order = 1
# AIC :  -43.682097880742134
# BIC :  -42.9211460595931
# FPE :  1.0693676351070205e-19
# HQIC:  -43.38345058362005
#
# Lag Order = 2
# AIC :  -47.518619986081134
# BIC :  -46.07059404148853
# FPE :  2.307125762328799e-21
# HQIC:  -46.95027115940101
#
# Lag Order = 3
# AIC :  -52.09549506467421
# BIC :  -49.95828310190267
# FPE :  2.375109490201219e-23
# HQIC:  -51.25656942130104
#
# Lag Order = 4
# AIC :  -54.07075095313262
# BIC :  -51.2422302764955
# FPE :  3.2996139616686965e-24
# HQIC:  -52.960368648983845
#
# Lag Order = 5
# AIC :  -54.08786956656628
# BIC :  -50.56590660276912
# FPE :  3.25125953097601e-24
# HQIC:  -52.7051461681267
#
# Lag Order = 6
# AIC :  -54.50835264732201
# ...

# %%
x = model.select_order(maxlags=12)
x.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# # **VAR MODEL**

# %%
model_fitted = model.fit(6)
model_fitted.summary()
# Out:
#   Summary of Regression Results
# ...
# Model:                         VAR
# Method:                        OLS
# Date:           Thu, 10, Mar, 2022
# Time:                     05:27:07
# --------------------------------------------------------------------
# No. of Equations:         9.00000    BIC:                   -50.2908
# Nobs:                     493.000    HQIC:                  -52.8524
# Log likelihood:           7635.48    FPE:                2.14274e-24
# AIC:                     -54.5084    Det(Omega_mle):     8.27115e-25
# --------------------------------------------------------------------
# Results for equation fit top 1
# ...
#                    coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------
# const                 0.002290         0.002084            1.099           0.272
# L1.fit top 1          2.176046         0.098116           22.178           0.000
# ...

# %% [markdown]
# **According to FPE and HQIC, the optimal lag is observed at a lag order of 5 or 6.Hence I take the p value as 6**

# %%
# Get the lag order
lag_order = model_fitted.k_ar
print(lag_order)  #> 4

# Input data for forecasting
forecast_input = train_diff.values[-lag_order:]
forecast_input
# Out:
# 6
# array([[ 0.00593991,  0.24277913,  0.0610397 ,  0.07188055,  0.07571509,
#          0.26777694,  0.24349298,  0.01657587,  0.01988498],
#        [-0.00138434,  0.21496989,  0.06994516,  0.08038106,  0.08381951,
#          0.23939489,  0.21283085,  0.00917221,  0.01244278],
#        [-0.00979057,  0.18814113,  0.07836048,  0.0882901 ,  0.09134504,
#          0.21170358,  0.18290309,  0.00069022,  0.00389231],
#        [-0.01897528,  0.16292208,  0.08600435,  0.09532217,  0.09801001,
#          0.18529018,  0.15430792, -0.00856585, -0.00546387],
#        [-0.02861422,  0.139861  ,  0.09260197,  0.10120178,  0.10354209,
#          0.1606706 ,  0.12757159, -0.01827152, -0.01530226],
#        [-0.0383721 ,  0.11941208,  0.09789221,  0.1056708 ,  0.10768561,
#          0.13827779,  0.10313648, -0.02809183, -0.02528816]])

# %% [markdown]
# # **Forecast**

# %%
# Forecast
fc = model_fitted.forecast(y=forecast_input, steps=126)
fc.shape
# Out:
# (126, 9)

# %%
test.shape
# Out:
# (126, 9)

# %%
df_forecast = pd.DataFrame(fc, index=test.index[-126:], columns=data.columns)
df_forecast
# Out:
#             fit top 1  fit top 2  fit top 3  fit2 top 3  fit3 top 3  \
# Date
# 2018-05-29  -0.049795   0.110109   0.091053    0.102141    0.102635
# 2018-05-30  -0.055567   0.134165   0.077887    0.092244    0.091551
# 2018-05-31  -0.048061   0.191224   0.061719    0.077196    0.075697
# 2018-06-01  -0.026013   0.252666   0.048473    0.062721    0.060736
# 2018-06-02   0.000555   0.282408   0.040622    0.051363    0.049274
# ...               ...        ...        ...         ...         ...
# 2018-09-27   0.018367   0.216508   0.074236    0.074656    0.075200
# 2018-09-28   0.016705   0.219014   0.078503    0.078731    0.079303
# 2018-09-29   0.016237   0.223062   0.079089    0.079171    0.079760
# 2018-09-30   0.017285   0.223224   0.075020    0.075211    0.075781
# 2018-10-01   0.018237   0.218315   0.070281    0.070768    0.071297
#
#             fit2 top 2  fit3 top 2  fit2 top 1  fit3 top 1
# Date
# 2018-05-29    0.135586    0.109165   -0.043604   -0.041443
# ...

# %%
def invert_transformation(train, df_forecast, second_diff=False):
    """Revert back the differencing to get the forecast to original scale."""
    df_fc = df_forecast.copy()
    columns = train.columns
    for col in columns:        
        # Roll back 2nd Diff
        if second_diff:
            df_fc[str(col)+'_1d'] = (train[col].iloc[-1]-train[col].iloc[-2]) + df_fc[str(col)+'_2d'].cumsum()
        # Roll back 1st Diff
        df_fc[str(col)+'_forecast'] = train[col].iloc[-1] + df_fc[str(col)].cumsum()
    return df_fc

# %%
df_results = invert_transformation(train, df_forecast, second_diff=False)        
df_results.loc[:,['fit top 1','fit top 2','fit top 3','fit2 top 3','fit3 top 3','fit2 top 2','fit3 top 2','fit2 top 1','fit3 top 1'] ]
# Out:
#             fit top 1  fit top 2  fit top 3  fit2 top 3  fit3 top 3  \
# Date
# 2018-05-29  -0.049795   0.110109   0.091053    0.102141    0.102635
# 2018-05-30  -0.055567   0.134165   0.077887    0.092244    0.091551
# 2018-05-31  -0.048061   0.191224   0.061719    0.077196    0.075697
# 2018-06-01  -0.026013   0.252666   0.048473    0.062721    0.060736
# 2018-06-02   0.000555   0.282408   0.040622    0.051363    0.049274
# ...               ...        ...        ...         ...         ...
# 2018-09-27   0.018367   0.216508   0.074236    0.074656    0.075200
# 2018-09-28   0.016705   0.219014   0.078503    0.078731    0.079303
# 2018-09-29   0.016237   0.223062   0.079089    0.079171    0.079760
# 2018-09-30   0.017285   0.223224   0.075020    0.075211    0.075781
# 2018-10-01   0.018237   0.218315   0.070281    0.070768    0.071297
#
#             fit2 top 2  fit3 top 2  fit2 top 1  fit3 top 1
# Date
# 2018-05-29    0.135586    0.109165   -0.043604   -0.041443
# ...

# %%
fig, axes = plt.subplots(nrows=int(len(data.columns)/3), ncols=3, dpi=150, figsize=(10,10))
for i, (col,ax) in enumerate(zip(data.columns, axes.flatten())):
    df_results[col+'_forecast'].plot(legend=True, ax=ax).autoscale(axis='x',tight=True)
    test[col][-126:].plot(legend=True, ax=ax);
    ax.set_title(col + ": Forecast vs Actuals")
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.tight_layout();

# %% [markdown]
# **Create a function for Evaluation Metrics Calculation**

# %%
def timeseries_evaluation_metrics_func(y_true, y_pred):  
    def mean_absolute_percentage_error(y_true, y_pred): 
        y_true, y_pred = np.array(y_true), np.array(y_pred)
        return np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    print('Evaluation metric results:-')
    print(f'MSE is : {metrics.mean_squared_error(y_true, y_pred)}')
    print(f'MAE is : {metrics.mean_absolute_error(y_true, y_pred)}')
    print(f'RMSE is : {np.sqrt(metrics.mean_squared_error(y_true, y_pred))}')
    print(f'MAPE is : {mean_absolute_percentage_error(y_true, y_pred)}')
    print(f'R2 is : {metrics.r2_score(y_true, y_pred)}',end='\n\n')

# %%
for i in ['fit top 1','fit top 2','fit top 3','fit2 top 3','fit3 top 3','fit2 top 2','fit3 top 2','fit2 top 1','fit3 top 1']:
    print(f'Evaluation metric for {i}')
    timeseries_evaluation_metrics_func(test[str(i)],df_results[str(i)])
# Out:
# Evaluation metric for fit top 1
# Evaluation metric results:-
# MSE is : 251.5426979224272
# MAE is : 15.85378966970931
# RMSE is : 15.86009766434076
# MAPE is : 99.91463673433934
# R2 is : -1261.359131599588
#
# Evaluation metric for fit top 2
# Evaluation metric results:-
# MSE is : 10934.302148865589
# MAE is : 104.51418312259806
# RMSE is : 104.56721354643427
# MAPE is : 99.79554202134227
# R2 is : -987.4200246834591
#
# Evaluation metric for fit top 3
# Evaluation metric results:-
# MSE is : 1685.1736001757663
# MAE is : 40.98174480241623
# RMSE is : 41.05086601005838
# MAPE is : 99.82517675929287
# R2 is : -297.0300250911935
#
# Evaluation metric for fit2 top 3
# Evaluation metric results:-
# MSE is : 1713.877645384632
# MAE is : 41.32435933745991
# RMSE is : 41.399005367093444
# MAPE is : 99.8253863439068
# R2 is : -277.2222486903208
#
# Evaluation metric for fit3 top 3
# Evaluation metric results:-
# MSE is : 1717.8758060658593
# MAE is : 41.36320374572478
# ...

# %% [markdown]
# #**Question 4:Briefly explain your choice of model, and how it performs better or worse than the provided predictions**

# %% [markdown]
# I choose the VAR Model because Vector Autoregression (VAR) is a multivariate forecasting algorithm that is used when two or more time series influence each other.
# That means, the basic requirements in order to use VAR are:
#
#
# 1.   You need at least two time series (variables)
# 2.   The time series should influence each other.
#
# It is considered as an Autoregressive model because, each variable (Time Series) is modeled as a function of the past values, that is the predictors are nothing but the lags (time delayed value) of the series. VAR is  different from other Autoregressive models like AR, ARMA or ARIMAin such a way these models are uni-directional, where, the predictors influence the Y and not vice-versa. Whereas, Vector Auto Regression (VAR) is bi-directional. That is, the variables influence each other.
#
# Hence I think this model will work for this type of dataset
